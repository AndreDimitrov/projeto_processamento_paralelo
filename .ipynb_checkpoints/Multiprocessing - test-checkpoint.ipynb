# %%
import requests
import json
import pandas as pd
from tqdm import tqdm
from time import sleep, time
from multiprocessing.pool import ThreadPool
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Requisição dos dados dos Deputados
url = 'https://dadosabertos.camara.leg.br/api/v2/deputados'
parametros = {}
resposta = requests.request("GET", url, params=parametros)
objetos = json.loads(resposta.text)
dados = objetivos['dados']

# %%
len(dados)
# Out:
# 513

# %%
dados[0]
# Out:
# {'id': 204554,
#  'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204554',
#  'nome': 'Abílio Santana',
#  'siglaPartido': 'PL',
#  'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#  'siglaUf': 'BA',
#  'idLegislatura': 56,
#  'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204554.jpg',
#  'email': 'dep.abiliosantana@camara.leg.br'}

# %%
# Selecionando todos os ids dos deputados
id = []
for i in range(len(dados)):
    id.append(str(dados[i]['id']))

# %%
id[:5]
# Out:
# ['204554', '204521', '204379', '204560', '204528']

# %% [markdown]
# ## Processamento individual por id

# %%
# Requisição dos dados detalhes dos deputados
def detalhe_deputado(id):
    url = 'https://dadosabertos.camara.leg.br/api/v2/deputados'
    parametros = {}
    resposta = requests.request("GET", url, params=parametros)
    objetos = json.loads(resposta.text)
    dados = objetos['dados']
    return dados

# %%
detalhe_deputado('204554')
# Out:
# [{'id': 204554,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204554',
#   'nome': 'Abílio Santana',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204554.jpg',
#   'email': 'dep.abiliosantana@camara.leg.br'},
#  {'id': 204521,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204521',
#   'nome': 'Abou Anni',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204521.jpg',
#   'email': 'dep.abouanni@camara.leg.br'},
#  {'id': 204379,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204379',
#   'nome': 'Acácio Favacho',
#   'siglaPartido': 'PROS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36763',
#   'siglaUf': 'AP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204379.jpg',
#   'email': 'dep.acaciofavacho@camara.leg.br'},
#  {'id': 204560,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204560',
#   'nome': 'Adolfo Viana',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204560.jpg',
#   'email': 'dep.adolfoviana@camara.leg.br'},
#  {'id': 204528,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204528',
#   'nome': 'Adriana Ventura',
#   'siglaPartido': 'NOVO',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37901',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204528.jpg',
#   'email': 'dep.adrianaventura@camara.leg.br'},
#  {'id': 121948,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/121948',
#   'nome': 'Adriano do Baldy',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'GO',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/121948.jpg',
#   'email': 'dep.adrianodobaldy@camara.leg.br'},
#  {'id': 74646,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74646',
#   'nome': 'Aécio Neves',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'MG',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74646.jpg',
#   'email': 'dep.aecioneves@camara.leg.br'},
#  {'id': 141372,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/141372',
#   'nome': 'Aelton Freitas',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'MG',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/141372.jpg',
#   'email': 'dep.aeltonfreitas@camara.leg.br'},
#  {'id': 160508,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160508',
#   'nome': 'Afonso Florence',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160508.jpg',
#   'email': 'dep.afonsoflorence@camara.leg.br'},
#  {'id': 136811,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/136811',
#   'nome': 'Afonso Hamm',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'RS',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/136811.jpg',
#   'email': 'dep.afonsohamm@camara.leg.br'},
#  {'id': 178835,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178835',
#   'nome': 'Afonso Motta',
#   'siglaPartido': 'PDT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36786',
#   'siglaUf': 'RS',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178835.jpg',
#   'email': 'dep.afonsomotta@camara.leg.br'},
#  {'id': 160527,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160527',
#   'nome': 'Aguinaldo Ribeiro',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'PB',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160527.jpg',
#   'email': 'dep.aguinaldoribeiro@camara.leg.br'},
#  {'id': 204495,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204495',
#   'nome': 'Airton Faleiro',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'PA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204495.jpg',
#   'email': 'dep.airtonfaleiro@camara.leg.br'},
#  {'id': 204549,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204549',
#   'nome': 'AJ Albuquerque',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'CE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204549.jpg',
#   'email': 'dep.ajalbuquerque@camara.leg.br'},
#  {'id': 178836,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178836',
#   'nome': 'Alan Rick',
#   'siglaPartido': 'DEM',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36769',
#   'siglaUf': 'AC',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178836.jpg',
#   'email': 'dep.alanrick@camara.leg.br'},
#  {'id': 160559,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160559',
#   'nome': 'Alceu Moreira',
#   'siglaPartido': 'MDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36899',
#   'siglaUf': 'RS',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160559.jpg',
#   'email': 'dep.alceumoreira@camara.leg.br'},
#  {'id': 204413,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204413',
#   'nome': 'Alcides Rodrigues',
#   'siglaPartido': 'PATRIOTA',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37907',
#   'siglaUf': 'GO',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204413.jpg',
#   'email': 'dep.alcidesrodrigues@camara.leg.br'},
#  {'id': 204545,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204545',
#   'nome': 'Alê Silva',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'MG',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204545.jpg',
#   'email': 'dep.alesilva@camara.leg.br'},
#  {'id': 204501,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204501',
#   'nome': 'Alencar Santana Braga',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204501.jpg',
#   'email': 'dep.alencarsantanabraga@camara.leg.br'},
#  {'id': 160511,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160511',
#   'nome': 'Alessandro Molon',
#   'siglaPartido': 'PSB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36832',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160511.jpg',
#   'email': 'dep.alessandromolon@camara.leg.br'},
#  {'id': 178972,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178972',
#   'nome': 'Alex Manente',
#   'siglaPartido': 'CIDADANIA',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37905',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178972.jpg',
#   'email': 'dep.alexmanente@camara.leg.br'},
#  {'id': 204571,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204571',
#   'nome': 'Alex Santana',
#   'siglaPartido': 'PDT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36786',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204571.jpg',
#   'email': 'dep.alexsantana@camara.leg.br'},
#  {'id': 204544,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204544',
#   'nome': 'Alexandre Frota',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204544.jpg',
#   'email': 'dep.alexandrefrota@camara.leg.br'},
#  {'id': 160545,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160545',
#   'nome': 'Alexandre Leite',
#   'siglaPartido': 'DEM',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36769',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160545.jpg',
#   'email': 'dep.alexandreleite@camara.leg.br'},
#  {'id': 204503,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204503',
#   'nome': 'Alexandre Padilha',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204503.jpg',
#   'email': 'dep.alexandrepadilha@camara.leg.br'},
#  {'id': 204516,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204516',
#   'nome': 'Alexis Fonteyne',
#   'siglaPartido': 'NOVO',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37901',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204516.jpg',
#   'email': 'dep.alexisfonteyne@camara.leg.br'},
#  {'id': 74057,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74057',
#   'nome': 'Alice Portugal',
#   'siglaPartido': 'PCdoB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36779',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74057.jpg',
#   'email': 'dep.aliceportugal@camara.leg.br'},
#  {'id': 178927,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178927',
#   'nome': 'Aliel Machado',
#   'siglaPartido': 'PSB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36832',
#   'siglaUf': 'PR',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178927.jpg',
#   'email': 'dep.alielmachado@camara.leg.br'},
#  {'id': 204353,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204353',
#   'nome': 'Aline Gurgel',
#   'siglaPartido': 'REPUBLICANOS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37908',
#   'siglaUf': 'AP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204353.jpg',
#   'email': 'dep.alinegurgel@camara.leg.br'},
#  {'id': 204400,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204400',
#   'nome': 'Aline Sleutjes',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'PR',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204400.jpg',
#   'email': 'dep.alinesleutjes@camara.leg.br'},
#  {'id': 178937,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178937',
#   'nome': 'Altineu Côrtes',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178937.jpg',
#   'email': 'dep.altineucortes@camara.leg.br'},
#  {'id': 178881,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178881',
#   'nome': 'Aluisio Mendes',
#   'siglaPartido': 'PSC',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36833',
#   'siglaUf': 'MA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178881.jpg',
#   'email': 'dep.aluisiomendes@camara.leg.br'},
#  {'id': 204356,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204356',
#   'nome': 'Amaro Neto',
#   'siglaPartido': 'REPUBLICANOS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37908',
#   'siglaUf': 'ES',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204356.jpg',
#   'email': 'dep.amaroneto@camara.leg.br'},
#  {'id': 178831,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178831',
#   'nome': 'André Abdon',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'AP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178831.jpg',
#   'email': 'dep.andreabdon@camara.leg.br'},
#  {'id': 74471,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74471',
#   'nome': 'André de Paula',
#   'siglaPartido': 'PSD',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36834',
#   'siglaUf': 'PE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74471.jpg',
#   'email': 'dep.andredepaula@camara.leg.br'},
#  {'id': 204423,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204423',
#   'nome': 'André Ferreira',
#   'siglaPartido': 'PSC',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36833',
#   'siglaUf': 'PE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204423.jpg',
#   'email': 'dep.andreferreira@camara.leg.br'},
#  {'id': 133439,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/133439',
#   'nome': 'André Figueiredo',
#   'siglaPartido': 'PDT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36786',
#   'siglaUf': 'CE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/133439.jpg',
#   'email': 'dep.andrefigueiredo@camara.leg.br'},
#  {'id': 178882,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178882',
#   'nome': 'André Fufuca',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'MA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178882.jpg',
#   'email': 'dep.andrefufuca@camara.leg.br'},
#  {'id': 204515,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204515',
#   'nome': 'André Janones',
#   'siglaPartido': 'AVANTE',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36898',
#   'siglaUf': 'MG',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204515.jpg',
#   'email': 'dep.andrejanones@camara.leg.br'},
#  {'id': 73696,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73696',
#   'nome': 'Angela Amin',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'SC',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/73696.jpg',
#   'email': 'dep.angelaamin@camara.leg.br'},
#  {'id': 74212,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74212',
#   'nome': 'Aníbal Gomes',
#   'siglaPartido': 'DEM',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36769',
#   'siglaUf': 'CE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74212.jpg',
#   'email': 'dep.anibalgomes@camara.leg.br'},
#  {'id': 160553,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160553',
#   'nome': 'Antonio Brito',
#   'siglaPartido': 'PSD',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36834',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160553.jpg',
#   'email': 'dep.antoniobrito@camara.leg.br'},
#  {'id': 73433,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73433',
#   'nome': 'Arlindo Chinaglia',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/73433.jpg',
#   'email': 'dep.arlindochinaglia@camara.leg.br'},
#  {'id': 141391,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/141391',
#   'nome': 'Arnaldo Jardim',
#   'siglaPartido': 'CIDADANIA',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37905',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/141391.jpg',
#   'email': 'dep.arnaldojardim@camara.leg.br'},
#  {'id': 204414,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204414',
#   'nome': 'Aroldo Martins',
#   'siglaPartido': 'REPUBLICANOS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37908',
#   'siglaUf': 'PR',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204414.jpg',
#   'email': 'dep.aroldomartins@camara.leg.br'},
#  {'id': 160541,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160541',
#   'nome': 'Arthur Lira',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'AL',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160541.jpg',
#   'email': 'dep.arthurlira@camara.leg.br'},
#  {'id': 160600,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160600',
#   'nome': 'Arthur Oliveira Maia',
#   'siglaPartido': 'DEM',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36769',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160600.jpg',
#   'email': 'dep.arthuroliveiramaia@camara.leg.br'},
#  {'id': 74090,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74090',
#   'nome': 'Átila Lins',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'AM',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74090.jpg',
#   'email': 'dep.atilalins@camara.leg.br'},
#  {'id': 74459,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74459',
#   'nome': 'Átila Lira',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'PI',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74459.jpg',
#   'email': 'dep.atilalira@camara.leg.br'},
#  {'id': 160665,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160665',
#   'nome': 'Augusto Coutinho',
#   'siglaPartido': 'SOLIDARIEDADE',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37904',
#   'siglaUf': 'PE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160665.jpg',
#   'email': 'dep.augustocoutinho@camara.leg.br'},
#  {'id': 204509,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204509',
#   'nome': 'Áurea Carolina',
#   'siglaPartido': 'PSOL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36839',
#   'siglaUf': 'MG',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204509.jpg',
#   'email': 'dep.aureacarolina@camara.leg.br'},
#  {'id': 160512,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160512',
#   'nome': 'Aureo Ribeiro',
#   'siglaPartido': 'SOLIDARIEDADE',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37904',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160512.jpg',
#   'email': 'dep.aureoribeiro@camara.leg.br'},
#  {'id': 69871,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/69871',
#   'nome': 'Bacelar',
#   'siglaPartido': 'PODE',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36896',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/69871.jpg',
#   'email': 'dep.bacelar@camara.leg.br'},
#  {'id': 178975,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178975',
#   'nome': 'Baleia Rossi',
#   'siglaPartido': 'MDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36899',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178975.jpg',
#   'email': 'dep.baleiarossi@camara.leg.br'},
#  {'id': 73701,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73701',
#   'nome': 'Benedita da Silva',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/73701.jpg',
#   'email': 'dep.beneditadasilva@camara.leg.br'},
#  {'id': 109429,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/109429',
#   'nome': 'Benes Leocádio',
#   'siglaPartido': 'REPUBLICANOS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37908',
#   'siglaUf': 'RN',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/109429.jpg',
#   'email': 'dep.benesleocadio@camara.leg.br'},
#  {'id': 141335,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/141335',
#   'nome': 'Beto Faro',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'PA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/141335.jpg',
#   'email': 'dep.betofaro@camara.leg.br'},
#  {'id': 204358,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204358',
#   'nome': 'Beto Pereira',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'MS',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204358.jpg',
#   'email': 'dep.betopereira@camara.leg.br'},
#  {'id': 178948,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178948',
#   'nome': 'Beto Rosado',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'RN',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178948.jpg',
#   'email': 'dep.betorosado@camara.leg.br'},
#  {'id': 207176,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/207176',
#   'nome': 'Bia Cavassa',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'MS',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/207176.jpg',
#   'email': 'dep.biacavassa@camara.leg.br'},
#  {'id': 204374,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204374',
#   'nome': 'Bia Kicis',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'DF',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204374.jpg',
#   'email': 'dep.biakicis@camara.leg.br'},
#  {'id': 204388,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204388',
#   'nome': 'Bibo Nunes',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'RS',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204388.jpg',
#   'email': 'dep.bibonunes@camara.leg.br'},
#  {'id': 141513,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/141513',
#   'nome': 'Bilac Pinto',
#   'siglaPartido': 'DEM',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36769',
#   'siglaUf': 'MG',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/141513.jpg',
#   'email': 'dep.bilacpinto@camara.leg.br'},
#  {'id': 204561,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204561',
#   'nome': 'Bira do Pindaré',
#   'siglaPartido': 'PSB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36832',
#   'siglaUf': 'MA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204561.jpg',
#   'email': 'dep.biradopindare@camara.leg.br'},
#  {'id': 204397,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204397',
#   'nome': 'Boca Aberta',
#   'siglaPartido': 'PROS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36763',
#   'siglaUf': 'PR',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204397.jpg',
#   'email': 'dep.bocaaberta@camara.leg.br'},
#  {'id': 160538,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160538',
#   'nome': 'Bohn Gass',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'RS',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160538.jpg',
#   'email': 'dep.bohngass@camara.leg.br'},
#  {'id': 74052,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74052',
#   'nome': 'Bosco Costa',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'SE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74052.jpg',
#   'email': 'dep.boscocosta@camara.leg.br'},
#  {'id': 204551,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204551',
#   'nome': 'Bosco Saraiva',
#   'siglaPartido': 'SOLIDARIEDADE',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37904',
#   'siglaUf': 'AM',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204551.jpg',
#   'email': 'dep.boscosaraiva@camara.leg.br'},
#  {'id': 204502,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204502',
#   'nome': 'Bozzella',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204502.jpg',
#   'email': 'dep.bozzella@camara.leg.br'},
#  {'id': 160589,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160589',
#   'nome': 'Bruna Furlan',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160589.jpg',
#   'email': 'dep.brunafurlan@camara.leg.br'},
#  {'id': 93083,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/93083',
#   'nome': 'Cacá Leão',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/93083.jpg',
#   'email': 'dep.cacaleao@camara.leg.br'},
#  {'id': 204352,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204352',
#   'nome': 'Camilo Capiberibe',
#   'siglaPartido': 'PSB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36832',
#   'siglaUf': 'AP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204352.jpg',
#   'email': 'dep.camilocapiberibe@camara.leg.br'},
#  {'id': 204572,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204572',
#   'nome': 'Capitão Alberto Neto',
#   'siglaPartido': 'REPUBLICANOS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37908',
#   'siglaUf': 'AM',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204572.jpg',
#   'email': 'dep.capitaoalbertoneto@camara.leg.br'},
#  {'id': 178829,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178829',
#   'nome': 'Capitão Augusto',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178829.jpg',
#   'email': 'dep.capitaoaugusto@camara.leg.br'},
#  {'id': 178924,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178924',
#   'nome': 'Capitão Fábio Abreu',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'PI',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178924.jpg',
#   'email': 'dep.capitaofabioabreu@camara.leg.br'},
#  {'id': 204487,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204487',
#   'nome': 'Capitão Wagner',
#   'siglaPartido': 'PROS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36763',
#   'siglaUf': 'CE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204487.jpg',
#   'email': 'dep.capitaowagner@camara.leg.br'},
#  {'id': 213762,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/213762',
#   'nome': 'Carla Dickson',
#   'siglaPartido': 'PROS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36763',
#   'siglaUf': 'RN',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/213762.jpg',
#   'email': 'dep.carladickson@camara.leg.br'},
#  {'id': 204507,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204507',
#   'nome': 'Carla Zambelli',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204507.jpg',
#   'email': 'dep.carlazambelli@camara.leg.br'},
#  {'id': 204361,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204361',
#   'nome': 'Carlos Chiodini',
#   'siglaPartido': 'MDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36899',
#   'siglaUf': 'SC',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204361.jpg',
#   'email': 'dep.carloschiodini@camara.leg.br'},
#  {'id': 178962,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178962',
#   'nome': 'Carlos Gomes',
#   'siglaPartido': 'REPUBLICANOS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37908',
#   'siglaUf': 'RS',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178962.jpg',
#   'email': 'dep.carlosgomes@camara.leg.br'},
#  {'id': 178993,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178993',
#   'nome': 'Carlos Henrique Gaguim',
#   'siglaPartido': 'DEM',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36769',
#   'siglaUf': 'TO',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178993.jpg',
#   'email': 'dep.carloshenriquegaguim@camara.leg.br'},
#  {'id': 204460,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204460',
#   'nome': 'Carlos Jordy',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204460.jpg',
#   'email': 'dep.carlosjordy@camara.leg.br'},
#  {'id': 74262,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74262',
#   'nome': 'Carlos Sampaio',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74262.jpg',
#   'email': 'dep.carlossampaio@camara.leg.br'},
#  {'id': 204426,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204426',
#   'nome': 'Carlos Veras',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'PE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204426.jpg',
#   'email': 'dep.carlosveras@camara.leg.br'},
#  {'id': 141398,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/141398',
#   'nome': 'Carlos Zarattini',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/141398.jpg',
#   'email': 'dep.carloszarattini@camara.leg.br'},
#  {'id': 164360,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/164360',
#   'nome': 'Carmen Zanotto',
#   'siglaPartido': 'CIDADANIA',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37905',
#   'siglaUf': 'SC',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/164360.jpg',
#   'email': 'dep.carmenzanotto@camara.leg.br'},
#  {'id': 204369,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204369',
#   'nome': 'Caroline de Toni',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'SC',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204369.jpg',
#   'email': 'dep.carolinedetoni@camara.leg.br'},
#  {'id': 204499,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204499',
#   'nome': 'Cássio Andrade',
#   'siglaPartido': 'PSB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36832',
#   'siglaUf': 'PA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204499.jpg',
#   'email': 'dep.cassioandrade@camara.leg.br'},
#  {'id': 204380,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204380',
#   'nome': 'Celina Leão',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'DF',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204380.jpg',
#   'email': 'dep.celinaleao@camara.leg.br'},
#  {'id': 204370,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204370',
#   'nome': 'Célio Moura',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'TO',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204370.jpg',
#   'email': 'dep.celiomoura@camara.leg.br'},
#  {'id': 178876,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178876',
#   'nome': 'Célio Silveira',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'GO',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178876.jpg',
#   'email': 'dep.celiosilveira@camara.leg.br'},
#  {'id': 204488,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204488',
#   'nome': 'Célio Studart',
#   'siglaPartido': 'PV',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36851',
#   'siglaUf': 'CE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204488.jpg',
#   'email': 'dep.celiostudart@camara.leg.br'},
#  {'id': 141405,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/141405',
#   'nome': 'Celso Maldaner',
#   'siglaPartido': 'MDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36899',
#   'siglaUf': 'SC',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/141405.jpg',
#   'email': 'dep.celsomaldaner@camara.leg.br'},
#  {'id': 73441,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73441',
#   'nome': 'Celso Russomanno',
#   'siglaPartido': 'REPUBLICANOS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37908',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/73441.jpg',
#   'email': 'dep.celsorussomanno@camara.leg.br'},
#  {'id': 204496,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204496',
#   'nome': 'Celso Sabino',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'PA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204496.jpg',
#   'email': 'dep.celsosabino@camara.leg.br'},
#  {'id': 204504,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204504',
#   'nome': 'Cezinha de Madureira',
#   'siglaPartido': 'PSD',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36834',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204504.jpg',
#   'email': 'dep.cezinhademadureira@camara.leg.br'},
#  {'id': 205476,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/205476',
#   'nome': 'Charles Fernandes',
#   'siglaPartido': 'PSD',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36834',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/205476.jpg',
#   'email': 'dep.charlesfernandes@camara.leg.br'},
#  {'id': 204490,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204490',
#   'nome': 'Charlles Evangelista',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'MG',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204490.jpg',
#   'email': 'dep.charllesevangelista@camara.leg.br'},
#  {'id': 141439,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/141439',
#   'nome': "Chico D'Angelo",
#   'siglaPartido': 'PDT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36786',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/141439.jpg',
#   'email': 'dep.chicodangelo@camara.leg.br'},
#  {'id': 204476,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204476',
#   'nome': 'Chiquinho Brazão',
#   'siglaPartido': 'AVANTE',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36898',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204476.jpg',
#   'email': 'dep.chiquinhobrazao@camara.leg.br'},
#  {'id': 204462,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204462',
#   'nome': 'Chris Tonietto',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204462.jpg',
#   'email': 'dep.christonietto@camara.leg.br'},
#  {'id': 178928,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178928',
#   'nome': 'Christiane de Souza Yared',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'PR',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178928.jpg',
#   'email': 'dep.christianedesouzayared@camara.leg.br'},
#  {'id': 204440,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204440',
#   'nome': 'Christino Aureo',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204440.jpg',
#   'email': 'dep.christinoaureo@camara.leg.br'},
#  {'id': 178939,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178939',
#   'nome': 'Clarissa Garotinho',
#   'siglaPartido': 'PROS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36763',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178939.jpg',
#   'email': 'dep.clarissagarotinho@camara.leg.br'},
#  {'id': 74537,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74537',
#   'nome': 'Claudio Cajado',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74537.jpg',
#   'email': 'dep.claudiocajado@camara.leg.br'},
#  {'id': 141408,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/141408',
#   'nome': 'Cleber Verde',
#   'siglaPartido': 'REPUBLICANOS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37908',
#   'siglaUf': 'MA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/141408.jpg',
#   'email': 'dep.cleberverde@camara.leg.br'},
#  {'id': 204376,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204376',
#   'nome': 'Coronel Armando',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'SC',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204376.jpg',
#   'email': 'dep.coronelarmando@camara.leg.br'},
#  {'id': 204378,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204378',
#   'nome': 'Coronel Chrisóstomo',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'RO',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204378.jpg',
#   'email': 'dep.coronelchrisostomo@camara.leg.br'},
#  {'id': 204514,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204514',
#   'nome': 'Coronel Tadeu',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204514.jpg',
#   'email': 'dep.coroneltadeu@camara.leg.br'},
#  {'id': 178963,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178963',
#   'nome': 'Covatti Filho',
#   'siglaPartido': 'PP',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37903',
#   'siglaUf': 'RS',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178963.jpg',
#   'email': 'dep.covattifilho@camara.leg.br'},
#  {'id': 135054,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/135054',
#   'nome': 'Cristiano Vale',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'PA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/135054.jpg',
#   'email': 'dep.cristianovale@camara.leg.br'},
#  {'id': 204355,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204355',
#   'nome': 'Da Vitoria',
#   'siglaPartido': 'CIDADANIA',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37905',
#   'siglaUf': 'ES',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204355.jpg',
#   'email': 'dep.davitoria@camara.leg.br'},
#  {'id': 141411,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/141411',
#   'nome': 'Dagoberto Nogueira',
#   'siglaPartido': 'PDT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36786',
#   'siglaUf': 'MS',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/141411.jpg',
#   'email': 'dep.dagobertonogueira@camara.leg.br'},
#  {'id': 74467,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74467',
#   'nome': 'Damião Feliciano',
#   'siglaPartido': 'PDT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36786',
#   'siglaUf': 'PB',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74467.jpg',
#   'email': 'dep.damiaofeliciano@camara.leg.br'},
#  {'id': 74060,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74060',
#   'nome': 'Daniel Almeida',
#   'siglaPartido': 'PCdoB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36779',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74060.jpg',
#   'email': 'dep.danielalmeida@camara.leg.br'},
#  {'id': 178916,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178916',
#   'nome': 'Daniel Coelho',
#   'siglaPartido': 'CIDADANIA',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37905',
#   'siglaUf': 'PE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178916.jpg',
#   'email': 'dep.danielcoelho@camara.leg.br'},
#  {'id': 204367,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204367',
#   'nome': 'Daniel Freitas',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'SC',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204367.jpg',
#   'email': 'dep.danielfreitas@camara.leg.br'},
#  {'id': 204454,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204454',
#   'nome': 'Daniel Silveira',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204454.jpg',
#   'email': 'dep.danielsilveira@camara.leg.br'},
#  {'id': 204409,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204409',
#   'nome': 'Daniel Trzeciak',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'RS',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204409.jpg',
#   'email': 'dep.danieltrzeciak@camara.leg.br'},
#  {'id': 204459,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204459',
#   'nome': 'Daniela do Waguinho',
#   'siglaPartido': 'MDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36899',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204459.jpg',
#   'email': 'dep.danieladowaguinho@camara.leg.br'},
#  {'id': 160528,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160528',
#   'nome': 'Danilo Cabral',
#   'siglaPartido': 'PSB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36832',
#   'siglaUf': 'PE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160528.jpg',
#   'email': 'dep.danilocabral@camara.leg.br'},
#  {'id': 62881,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/62881',
#   'nome': 'Danilo Forte',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'CE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/62881.jpg',
#   'email': 'dep.daniloforte@camara.leg.br'},
#  {'id': 116379,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/116379',
#   'nome': 'Darci de Matos',
#   'siglaPartido': 'PSD',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36834',
#   'siglaUf': 'SC',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/116379.jpg',
#   'email': 'dep.darcidematos@camara.leg.br'},
#  {'id': 205548,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/205548',
#   'nome': 'David Miranda',
#   'siglaPartido': 'PSOL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36839',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/205548.jpg',
#   'email': 'dep.davidmiranda@camara.leg.br'},
#  {'id': 204511,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204511',
#   'nome': 'David Soares',
#   'siglaPartido': 'DEM',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36769',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204511.jpg',
#   'email': 'dep.davidsoares@camara.leg.br'},
#  {'id': 204451,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204451',
# ...
#  {'id': 178922,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178922',
#   'nome': 'Tadeu Alencar',
#   'siglaPartido': 'PSB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36832',
#   'siglaUf': 'PE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178922.jpg',
#   'email': 'dep.tadeualencar@camara.leg.br'},
#  {'id': 204464,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204464',
#   'nome': 'Talíria Petrone',
#   'siglaPartido': 'PSOL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36839',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204464.jpg',
#   'email': 'dep.taliriapetrone@camara.leg.br'},
#  {'id': 206231,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/206231',
#   'nome': 'Ted Conti',
#   'siglaPartido': 'PSB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36832',
#   'siglaUf': 'ES',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/206231.jpg',
#   'email': 'dep.tedconti@camara.leg.br'},
#  {'id': 204466,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204466',
#   'nome': 'Tereza Nelma',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'AL',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204466.jpg',
#   'email': 'dep.terezanelma@camara.leg.br'},
#  {'id': 178862,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178862',
#   'nome': 'Tia Eron',
#   'siglaPartido': 'REPUBLICANOS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37908',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178862.jpg',
#   'email': 'dep.tiaeron@camara.leg.br'},
#  {'id': 143084,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/143084',
#   'nome': 'Tiago Dimas',
#   'siglaPartido': 'SOLIDARIEDADE',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37904',
#   'siglaUf': 'TO',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/143084.jpg',
#   'email': 'dep.tiagodimas@camara.leg.br'},
#  {'id': 204519,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204519',
#   'nome': 'Tiago Mitraud',
#   'siglaPartido': 'NOVO',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37901',
#   'siglaUf': 'MG',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204519.jpg',
#   'email': 'dep.tiagomitraud@camara.leg.br'},
#  {'id': 160976,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160976',
#   'nome': 'Tiririca',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160976.jpg',
#   'email': 'dep.tiririca@camara.leg.br'},
#  {'id': 197438,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/197438',
#   'nome': 'Tito',
#   'siglaPartido': 'AVANTE',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36898',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/197438.jpg',
#   'email': 'dep.tito@camara.leg.br'},
#  {'id': 178934,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178934',
#   'nome': 'Toninho Wandscheer',
#   'siglaPartido': 'PROS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36763',
#   'siglaUf': 'PR',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178934.jpg',
#   'email': 'dep.toninhowandscheer@camara.leg.br'},
#  {'id': 216545,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/216545',
#   'nome': 'Totonho Lopes',
#   'siglaPartido': 'PDT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36786',
#   'siglaUf': 'CE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/216545.jpg',
#   'email': 'dep.totonholopes@camara.leg.br'},
#  {'id': 157130,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/157130',
#   'nome': 'Túlio Gadêlha',
#   'siglaPartido': 'PDT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36786',
#   'siglaUf': 'PE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/157130.jpg',
#   'email': 'dep.tuliogadelha@camara.leg.br'},
#  {'id': 178863,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178863',
#   'nome': 'Uldurico Junior',
#   'siglaPartido': 'PROS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36763',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178863.jpg',
#   'email': 'dep.ulduricojunior@camara.leg.br'},
#  {'id': 195866,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/195866',
#   'nome': 'Vaidon Oliveira',
#   'siglaPartido': 'PROS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36763',
#   'siglaUf': 'CE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/195866.jpg',
#   'email': 'dep.vaidonoliveira@camara.leg.br'},
#  {'id': 204385,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204385',
#   'nome': 'Valdevan Noventa',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'SE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204385.jpg',
#   'email': 'dep.valdevannoventa@camara.leg.br'},
#  {'id': 160610,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160610',
#   'nome': 'Valmir Assunção',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160610.jpg',
#   'email': 'dep.valmirassuncao@camara.leg.br'},
#  {'id': 141552,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/141552',
#   'nome': 'Valtenir Pereira',
#   'siglaPartido': 'MDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36899',
#   'siglaUf': 'MT',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/141552.jpg',
#   'email': 'dep.valtenirpereira@camara.leg.br'},
#  {'id': 74376,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74376',
#   'nome': 'Vander Loubet',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'MS',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74376.jpg',
#   'email': 'dep.vanderloubet@camara.leg.br'},
#  {'id': 141553,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/141553',
#   'nome': 'Vanderlei Macris',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/141553.jpg',
#   'email': 'dep.vanderleimacris@camara.leg.br'},
#  {'id': 204505,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204505',
#   'nome': 'Vavá Martins',
#   'siglaPartido': 'REPUBLICANOS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37908',
#   'siglaUf': 'PA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204505.jpg',
#   'email': 'dep.vavamartins@camara.leg.br'},
#  {'id': 204396,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204396',
#   'nome': 'Vermelho',
#   'siglaPartido': 'PSD',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36834',
#   'siglaUf': 'PR',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204396.jpg',
#   'email': 'dep.vermelho@camara.leg.br'},
#  {'id': 74283,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74283',
#   'nome': 'Vicentinho',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74283.jpg',
#   'email': 'dep.vicentinho@camara.leg.br'},
#  {'id': 137070,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/137070',
#   'nome': 'Vicentinho Júnior',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'TO',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/137070.jpg',
#   'email': 'dep.vicentinhojunior@camara.leg.br'},
#  {'id': 204483,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204483',
#   'nome': 'Vilson da Fetaemg',
#   'siglaPartido': 'PSB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36832',
#   'siglaUf': 'MG',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204483.jpg',
#   'email': 'dep.vilsondafetaemg@camara.leg.br'},
#  {'id': 141555,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/141555',
#   'nome': 'Vinicius Carvalho',
#   'siglaPartido': 'REPUBLICANOS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37908',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/141555.jpg',
#   'email': 'dep.viniciuscarvalho@camara.leg.br'},
#  {'id': 204478,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204478',
#   'nome': 'Vinicius Farah',
#   'siglaPartido': 'MDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36899',
#   'siglaUf': 'RJ',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204478.jpg',
#   'email': 'dep.viniciusfarah@camara.leg.br'},
#  {'id': 160591,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160591',
#   'nome': 'Vinicius Gurgel',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'AP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160591.jpg',
#   'email': 'dep.viniciusgurgel@camara.leg.br'},
#  {'id': 204532,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204532',
#   'nome': 'Vinicius Poit',
#   'siglaPartido': 'NOVO',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37901',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204532.jpg',
#   'email': 'dep.viniciuspoit@camara.leg.br'},
#  {'id': 179587,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/179587',
#   'nome': 'Vitor Hugo',
#   'siglaPartido': 'PSL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837',
#   'siglaUf': 'GO',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/179587.jpg',
#   'email': 'dep.vitorhugo@camara.leg.br'},
#  {'id': 178992,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178992',
#   'nome': 'Vitor Lippi',
#   'siglaPartido': 'PSDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36835',
#   'siglaUf': 'SP',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178992.jpg',
#   'email': 'dep.vitorlippi@camara.leg.br'},
#  {'id': 215044,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/215044',
#   'nome': 'Vivi Reis',
#   'siglaPartido': 'PSOL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36839',
#   'siglaUf': 'PA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/215044.jpg',
#   'email': 'dep.vivireis@camara.leg.br'},
#  {'id': 160569,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160569',
#   'nome': 'Waldenor Pereira',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160569.jpg',
#   'email': 'dep.waldenorpereira@camara.leg.br'},
#  {'id': 178952,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178952',
#   'nome': 'Walter Alves',
#   'siglaPartido': 'MDB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36899',
#   'siglaUf': 'RN',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178952.jpg',
#   'email': 'dep.walteralves@camara.leg.br'},
#  {'id': 160518,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160518',
#   'nome': 'Weliton Prado',
#   'siglaPartido': 'PROS',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36763',
#   'siglaUf': 'MG',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160518.jpg',
#   'email': 'dep.welitonprado@camara.leg.br'},
#  {'id': 74043,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74043',
#   'nome': 'Wellington Roberto',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'PB',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74043.jpg',
#   'email': 'dep.wellingtonroberto@camara.leg.br'},
#  {'id': 74044,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74044',
#   'nome': 'Wilson Santiago',
#   'siglaPartido': 'PTB',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36845',
#   'siglaUf': 'PB',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74044.jpg',
#   'email': 'dep.wilsonsantiago@camara.leg.br'},
#  {'id': 74439,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74439',
#   'nome': 'Wolney Queiroz',
#   'siglaPartido': 'PDT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36786',
#   'siglaUf': 'PE',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/74439.jpg',
#   'email': 'dep.wolneyqueiroz@camara.leg.br'},
#  {'id': 178889,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178889',
#   'nome': 'Zé Carlos',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'MA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178889.jpg',
#   'email': 'dep.zecarlos@camara.leg.br'},
#  {'id': 204559,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204559',
#   'nome': 'Zé Neto',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'BA',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204559.jpg',
#   'email': 'dep.zeneto@camara.leg.br'},
#  {'id': 160632,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160632',
#   'nome': 'Zé Silva',
#   'siglaPartido': 'SOLIDARIEDADE',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37904',
#   'siglaUf': 'MG',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160632.jpg',
#   'email': 'dep.zesilva@camara.leg.br'},
#  {'id': 204517,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204517',
#   'nome': 'Zé Vitor',
#   'siglaPartido': 'PL',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#   'siglaUf': 'MG',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204517.jpg',
#   'email': 'dep.zevitor@camara.leg.br'},
#  {'id': 160592,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160592',
#   'nome': 'Zeca Dirceu',
#   'siglaPartido': 'PT',
#   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#   'siglaUf': 'PR',
#   'idLegislatura': 56,
#   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/160592.jpg',
#   'email': 'dep.zecadirceu@camara.leg.br'}]

# %%
inicio_processo = time()
deputado = detalhe_deputado('204521')
fim_processo = time()
processamento_individual = fim_processo - inicio_processo
print('Processamento individual por id:', round( (processamento_individual), 1), 'segundos')
# Out:
# Processamento individual por id: 0.5 segundos

# %%
ids = id[:100]

# %%
inicio_processo = time()
lista_api = []
for i in tqdm(ids):
    resultado_individual = detalhe_deputado(i)
    lista_api.append(resultado_individual)
fim_processo = time()    
processamento_sequencial = fim_processo - inicio_processo
print('Processamento sequencial por id:', round((processamento_sequencial), 1), 'segundos')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:51<00:00,  1.92it/s]
# Processamento sequencial por id: 52.0 segundos

# %%
# Subprocessos para requisição em paralelo na API
inicio_processo = time()

subprocessos = []
pool = ThreadPool(processes=10)

for i in tqdm(ids):
    resultado_paralelo = pool.apply_async(detalhe_deputado, (i, ))
    subprocessos.append(resultado_paralelo)
lista_api_paralela = [result.get(timeout=120) for result in tqdm(subprocessos)]

fim_processo = time()
processamento_paralelo = fim_processo - inicio_processo
print('Processamento paralelo dos id:', round( (processamento_paralelo), 1 ), 'segundos')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 5885.75it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:20<00:00,  4.78it/s]
# Processamento paralelo dos id: 21.1 segundos
